# %% [markdown]
# <a href="https://colab.research.google.com/github/Sashka123123/CHM/blob/main/%D0%BF%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%BD%D0%B012.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x, y):
    return x + np.sin(y/np.sqrt(0.3))

a = 0.5
b = 1.5
h = 0.1
y0 = 0.6

n = int((b - a) / h)

x = np.linspace(a, b, n+1)

y = np.zeros(n+1)
y[0] = y0

for i in range(n):
    y[i+1] = y[i] + f(x[i], y[i]) * h

y_rounded=np.round_(y,4)
print("x=",x, "\ny=",y_rounded)

plt.plot(x,y, "o",x,y, "red")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Метод Ейлера")
plt.legend(["точки", "x + np.sin(y/np.sqrt(0.3))"])
plt.grid()
plt.show()
# Out:
# x= [0.5 0.6 0.7 0.8 0.9 1.  1.1 1.2 1.3 1.4 1.5]
# y= [0.6    0.7389 0.8965 1.0662 1.2393 1.4063 1.5606 1.6994 1.8233 1.9347
#  2.0366]

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

a = 0.5
b = 1.5
h = 0.1

def model(y,x):
     return x + np.sin(y/np.sqrt(0.3))
y0 = 0.6

x = np.linspace(a, b, n+1)
y = odeint(model,y0,x)
print('x=', x)
print('y=',y)

plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Розв’язання диф. рівняння')
plt.grid()
plt.show()
# Out:
# x= [0.5 0.6 0.7 0.8 0.9 1.  1.1 1.2 1.3 1.4 1.5]
# y= [[0.6       ]
#  [0.74890737]
#  [0.91338012]
#  [1.08480243]
#  [1.25391799]
#  [1.41347391]
#  [1.55961766]
#  [1.69164462]
#  [1.81090282]
#  [1.91971868]
#  [2.02070049]]

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x, y):
    return x + np.cos(y/np.sqrt(0.3))

a = 0.7
b = 1.7
h = 0.1
y0 = 2.1
n = int((b - a) / h)

x = np.linspace(a, b, n+1)
y = np.zeros(n+1)
y[0] = y0

for i in range(n):
    y[i+1]=y[i]+(f(x[i],y[i])+f(x[i+1],y[i])+h*f(x[i],y[i]))*h/2

print("x =", x, "\ny =", y)
plt.plot(x,y, "o",x,y, "red")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Метод Ейлера-Коші")
plt.legend(["точки", "x + np.cos(y/np.sqrt(0.3))"])
plt.grid()
plt.show()
# Out:
# x = [0.7 0.8 0.9 1.  1.1 1.2 1.3 1.4 1.5 1.6 1.7]
# y = [2.1        2.09768418 2.10558566 2.12495766 2.15727924 2.20440258
#  2.26875107 2.35356892 2.46319749 2.60327281 2.78052574]

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

a = 0.7
b = 1.7
h = 0.1

def model(y,x):
    return x + np.cos(y/np.sqrt(0.3))
y0 = 2.1

x = np.linspace(a, b, n+1)
y = odeint(model,y0,x)
print('x=', x)
print('y=',y)

plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Розв’язання диф. рівняння')
plt.grid()
plt.show()
# Out:
# x= [0.7 0.8 0.9 1.  1.1 1.2 1.3 1.4 1.5 1.6 1.7]
# y= [[2.1       ]
#  [2.09781086]
#  [2.10595755]
#  [2.1257499 ]
#  [2.1587949 ]
#  [2.20717865]
#  [2.27371004]
#  [2.36222117]
#  [2.47785616]
#  [2.62708817]
#  [2.81675514]]
